# %% [markdown]
# # AI RECEIPE GENERATOR FROM THE GIVEN LIST OF INGREDIENTS

# %%
# !pip install -q --upgrade langchain langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 37.8 MB/s eta 0:00:00

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.9

# %%
from langchain_core.prompts import PromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from google.colab import userdata
import os

os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# %%
prompt = PromptTemplate(
    input_variables=["ingredients"],
    template="""
Generate a recipe using:

{ingredients}

Format:

# Recipe Name

## Ingredients
- item 1
- item 2

## Procedure
1. Step 1
2. Step 2
3. Step 3
"""
)

# %%
chain = prompt | llm

# %%
ingredients = input("🥕 Enter ingredients: ")
# Out:
# 🥕 Enter ingredients: gongura,chicken

# %%
result = chain.invoke(
    {"ingredients": ingredients}
)

# %%
from IPython.display import Markdown, display

display(Markdown(result.content))
# Out:
# # Gongura Chicken Curry
#
# ## Ingredients
# - 1 kg chicken, curry cut
# - 2-3 bunches gongura (sorrel leaves), washed and destemmed
# - 2 large onions, thinly sliced
# - 4-6 green chilies, slit (adjust to your spice preference)
# - 2 tablespoons ginger-garlic paste
# - 1 teaspoon turmeric powder
# - 1-2 teaspoons red chili powder (adjust to your spice preference)
# - 2 teaspoons coriander powder
# - 1 teaspoon cumin powder
# - 1/2 teaspoon garam masala (optional)
# - 3-4 tablespoons cooking oil
# - Salt to taste
# - 1/2 cup water (or as needed)
# - Fresh coriander leaves, chopped (for garnish, optional)
#
# **For Tempering (Optional):**
# - 1 teaspoon mustard seeds
# - 1 sprig curry leaves
# - 2-3 dry red chilies
#
# ## Procedure
# 1.  **Prepare Gongura:** Wash the gongura leaves thoroughly and separate them from the stems. You can either finely chop the leaves or blanch them lightly for 2-3 minutes, then blend into a coarse paste with 1-2 green chilies. Set aside.
# 2.  **Marinate Chicken (Optional):** In a bowl, marinate the chicken pieces with 1/2 teaspoon turmeric powder, 1 teaspoon red chili powder, and a pinch of salt. Mix well and set aside for 15-30 minutes.
# 3.  **Sauté Aromatics:** Heat oil in a heavy-bottomed pan or pot over medium heat. If using tempering, add mustard seeds, dry red chilies, and curry leaves. Let them splutter. Then add the sliced onions and remaining green chilies. Sauté until the onions turn golden brown, about 8-10 minutes.
# 4.  **Add Ginger-Garlic Paste:** Add the ginger-garlic paste and sauté for 1-2 minutes until the raw smell disappears.
# 5.  **Cook Chicken:** Add the marinated chicken pieces (or plain chicken if not marinated). Increase heat to medium-high and sauté for 5-7 minutes until the chicken changes color and is lightly browned on the edges.
# 6.  **Add Spices:** Reduce the heat to low. Add the remaining turmeric powder, red chili powder, coriander powder, and cumin powder. Mix well and cook for 1-2 minutes until fragrant, being careful not to burn the spices.
# 7.  **Incorporate Gongura:** Add the prepared gongura (chopped leaves or paste) to the pan. Mix thoroughly with the chicken and spices. Cook on medium-low heat for 8-10 minutes, stirring occasionally, until the gongura softens, blends well, and the oil starts to separate from the mixture. This step is crucial for the gongura to cook out its raw sourness.
# 8.  **Simmer the Curry:** Add about 1/2 cup of water (or more if you prefer a thinner gravy) and salt to taste. Bring the mixture to a boil, then reduce the heat to low, cover the pan, and simmer for 15-20 minutes, or until the chicken is tender and cooked through. Stir occasionally to prevent sticking.
# 9.  **Finish and Garnish:** Check for seasoning and adjust if necessary. If using, sprinkle garam masala and mix well. Garnish with fresh chopped coriander leaves.
# 10. **Serve:** Serve hot with steamed rice, roti, or chapati.
